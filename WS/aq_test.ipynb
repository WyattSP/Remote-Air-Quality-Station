# %% [markdown]
# # Test the AQ Sensor

# %%
# Set User Paths #
src_path = "/Users/wyatt.petryshen/Documents/GitHub/Remote-Air-Quality-Station/libs"

# %%
import os
os.chdir(src_path)

from sds011sensor import *
import time
from datetime import datetime

# %%
sensor = SDS011("/dev/tty.usbserial-110")

# %%
# SDS011 data
sensor.sleep(False)
time.sleep(5)
data = sensor.query()
sensor.sleep(True)
print(data)
# Out:
# None

# %%
pm2_5, pm10 = data
print(f"PM2.5: {pm2_5}, PM10: {pm10}")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 pm2_5, pm10 = data
#       2 print(f"PM2.5: {pm2_5}, PM10: {pm10}")
#
# TypeError: cannot unpack non-iterable NoneType object
